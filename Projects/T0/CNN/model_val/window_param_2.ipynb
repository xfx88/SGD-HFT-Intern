# %%
import datetime

import numpy as np
import matplotlib.pyplot as plt

import torch
torch.device('cuda:1')
import torch.nn as nn

from torch.utils.data import DataLoader, random_split
from src.dataset import HFTestDataset
from tqdm import tqdm
import seaborn as sns

import gc
from tst import Transformer
import tst.utilities as ut

# %%
# del HFTestDataset
# gc.collect()

# %%
tOpt = ut.TrainingOptions(BATCH_SIZE=8,
                          NUM_WORKERS=4,
                          LR=1e-3,
                          EPOCHS=100,
                          N_stack=3,
                          heads=2,
                          query=8,
                          value=8,
                          d_model=128,
                          d_input=43,
                          d_output=1,
                          attention_size = 50,
                          window = 200,
                          padding = 50,
                          chunk_mode = 'window'
                          )

# %%
model_path = '../train_dir/model/transformer/param_comb_4/'
model_name = 'ddpTransformer_epoch_60.pth.tar'

# %%
import os

# %%
model_data = torch.load(os.path.join(model_path, model_name))

# %%
os.path.join(model_path, model_name)
# Out:
# '../train_dir/model/transformer/param_comb_4/ddpTransformer_epoch_60.pth.tar'

# %%
from collections import OrderedDict
local_state_dict = OrderedDict()
for k, v in model_data['state_dict'].items():
    name = k[7:] # remove 'module.' of DataParallel/DistributedDataParallel
    local_state_dict[name] = v

# %%
model_data['state_dict']
# Out:
# OrderedDict([('module.layers_encoding.0._selfAttention._future_mask',
#               tensor([[False,  True,  True,  ...,  True,  True,  True],
#                       [False, False,  True,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       ...,
#                       [False, False, False,  ..., False,  True,  True],
#                       [False, False, False,  ..., False, False,  True],
#                       [False, False, False,  ..., False, False, False]], device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._attention_mask',
#               tensor([[False, False, False,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       ...,
#                       [ True,  True,  True,  ..., False, False, False],
#                       [ True,  True,  True,  ..., False, False, False],
#                       [ True,  True,  True,  ..., False, False, False]], device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._W_q.weight',
#               tensor([[-0.0278, -0.0110,  0.0109,  ..., -0.0221, -0.0903,  0.0446],
#                       [-0.0634,  0.0556, -0.0116,  ..., -0.0315,  0.0834,  0.0721],
#                       [ 0.0924, -0.0144, -0.0196,  ...,  0.0653,  0.0780,  0.0385],
#                       ...,
#                       [-0.0577, -0.0578, -0.0559,  ..., -0.0323,  0.0014,  0.0396],
#                       [ 0.0556,  0.0176,  0.0153,  ...,  0.0003,  0.0389,  0.0534],
#                       [-0.0510, -0.0594,  0.0042,  ..., -0.0749,  0.0141,  0.0160]],
#                      device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._W_q.bias',
#               tensor([-0.0040,  0.0518,  0.0073,  0.0546,  0.0509, -0.0187, -0.0947,  0.0061,
#                        0.0378,  0.0420,  0.0381, -0.0432,  0.0126, -0.0525, -0.0207, -0.0811],
#                      device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._W_k.weight',
#               tensor([[-0.0432, -0.0986,  0.0343,  ..., -0.0373,  0.0116, -0.0792],
#                       [ 0.0201, -0.0070,  0.0004,  ...,  0.0705,  0.0427,  0.0574],
#                       [ 0.0715, -0.0137, -0.0505,  ..., -0.0720, -0.0182,  0.0266],
#                       ...,
#                       [ 0.0079, -0.0079,  0.0195,  ...,  0.0976, -0.0204,  0.0261],
#                       [-0.0831, -0.0537, -0.0179,  ...,  0.0285, -0.0102,  0.0171],
#                       [ 0.0209,  0.0073,  0.0970,  ..., -0.0741,  0.0102,  0.0050]],
#                      device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._W_k.bias',
#               tensor([ 0.0664,  0.0123,  0.0231, -0.0552,  0.0557,  0.0786, -0.0152, -0.0538,
#                        0.0734,  0.0246,  0.0331, -0.0849,  0.0854,  0.0263, -0.0052, -0.0288],
#                      device='cuda:0')),
#              ('module.layers_encoding.0._selfAttention._W

#                      device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_q.bias',
#               tensor([ 0.0456,  0.1288,  0.0811,  0.0179,  0.0817, -0.0151, -0.0499,  0.0431,
#                       -0.0026,  0.0049, -0.1018,  0.0302,  0.0309, -0.0019, -0.0825, -0.0781],
#                      device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_k.weight',
#               tensor([[-4.6782e-02,  2.1075e-03,  4.3062e-02,  ..., -5.5938e-02,
#                        -2.8484e-02,  4.4976e-02],
#                       [-2.6973e-02, -3.4872e-02, -4.1127e-02,  ..., -2.9009e-02,
#                         3.7484e-02,  4.8160e-03],
#                       [-4.4977e-02, -6.2634e-02, -1.8680e-02,  ...,  4.8612e-02,
#                         1.5916e-02, -6.7767e-02],
#                       ...,
#                       [ 4.7338e-02,  9.8907e-02,  7.8679e-02,  ...,  9.5268e-03,
#                        -1.1966e-02,  7.6816e-02],
#                       [ 3.6231e-02,  1.0275e-02,  2.6552e-02,  ..., -2.6323e-05,
#                         3.3452e-02,  1.4748e-02],
#                       [ 8.4574e-02,  6.0389e-02, -3.5591e-02,  ...,  8.4862e-02,
#                        -1.1149e-02, -8.6287e-02]], device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_k.bias',
#               tensor([ 0.0786, -0.0290,  0.0431,  0.0077, -0.0602,  0.0856,  0.0293,  0.0686,
#                        0.0789,  0.0072,  0.0465, -0.0287, -0.0459, -0.0175,  0.0675,  0.0656],
#                      device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_v.weight',
#               tensor([[ 0.0601,  0.1029,  0.0114,  ..., -0.0506,  0.0445,  0.0166],
#                       [-0.0416, -0.0134, -0.0571,  ..., -0.0162, -0.0199, -0.0507],
#                       [-0.0344, -0.0151, -0.0068,  ...,  0.0760,  0.0618,  0.0890],
#                       ...,
#                       [ 0.0301,  0.0780,  0.0094,  ..., -0.0335, -0.0205, -0.0834],
#                       [-0.1102,  0.0675, -0.0126,  ..., -0.0738,  0.0218, -0.0861],
#                       [ 0.0627, -0.0915, -0.0200,  ...,  0.0522,  0.0060, -0.0334]],
#                      device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_v.bias',
#               tensor([ 0.0141, -0.0001, -0.0845,  0.0809, -0.0017,  0.0419,  0.0391, -0.0643,
#                        0.0926, -0.0222, -0.0233, -0.0843, -0.0833, -0.0258,  0.0470,  0.0878],
#                      device='cuda:0')),
#              ('module.layers_encoding.1._selfAttention._W_o.weight',
#               tensor([[ 0.0370, -0.1572, -0.1809,  ...,  0.1449,  0.2379,  0.1872],
#                       [-0.1562,  0.1249,  0.2059,  ...,  0.1347,  0.1591,  0.1258],
#                       [-0.1325,  0.0947, -0.1741,  ..., -0.2391,  0.1454, -0.2822],
#                       ...,
#                       [ 0.0390, -0.1264,  0.0509,  ...,  0.0443,  0.1460, -0.0876],
#                       [ 0.1656,  0.1605, -0.2044,  ...,  0.0286, -0.0458,  0.0187],
#                       [ 0.2819, -0.0638,  0.0032,  ..., -0.1362, -0.1250,  0.1980]],
#                      device='cuda:0')),
#              ('module.layers_encoding.1

#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._future_mask',
#               tensor([[False,  True,  True,  ...,  True,  True,  True],
#                       [False, False,  True,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       ...,
#                       [False, False, False,  ..., False,  True,  True],
#                       [False, False, False,  ..., False, False,  True],
#                       [False, False, False,  ..., False, False, False]], device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._attention_mask',
#               tensor([[False, False, False,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       [False, False, False,  ...,  True,  True,  True],
#                       ...,
#                       [ True,  True,  True,  ..., False, False, False],
#                       [ True,  True,  True,  ..., False, False, False],
#                       [ True,  True,  True,  ..., False, False, False]], device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_q.weight',
#               tensor([[ 0.0601, -0.0521, -0.0928,  ...,  0.0495,  0.0009,  0.0901],
#                       [-0.0099,  0.0159,  0.0859,  ...,  0.0302,  0.0782,  0.0213],
#                       [-0.0136, -0.0274,  0.0882,  ..., -0.0572, -0.0589, -0.0139],
#                       ...,
#                       [ 0.0267, -0.1021, -0.0442,  ...,  0.0509, -0.0185,  0.0910],
#                       [ 0.0463, -0.0555,  0.0085,  ..., -0.0391, -0.1164, -0.0501],
#                       [ 0.1095, -0.0562,  0.0763,  ..., -0.0792, -0.0743,  0.0611]],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_q.bias',
#               tensor([-0.1005, -0.0693,  0.0483,  0.0422, -0.1177, -0.0220, -0.0326, -0.1459,
#                        0.1026,  0.0855, -0.0929, -0.0775,  0.1207,  0.0021, -0.0600,  0.0186],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_k.weight',
#               tensor([[-0.0088,  0.0106,  0.0181,  ..., -0.0171,  0.0247, -0.0842],
#                       [ 0.1295, -0.0565,  0.0794,  ..., -0.0622,  0.0496, -0.0541],
#                       [-0.0360, -0.0701,  0.1018,  ...,  0.0048, -0.0193, -0.0775],
#                       ...,
#                       [-0.1073, -0.0003,  0.0329,  ..., -0.0504, -0.0325, -0.0654],
#                       [-0.0340, -0.0111,  0.0784,  ...,  0.0988, -0.0544, -0.0651],
#                       [ 0.0451,  0.0265, -0.0229,  ...,  0.0888, -0.0621,  0.0417]],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_k.bias',
#               tensor([-6.1205e-02,  2.8943e-02, -7.0658e-02, -5.9164e-03,  7.1932e-02,
#                        2.6694e-02, -1.6510e-02,  7.9299e-02,  1.5773e-02, -2.3190e-02,
#                       -7.7002e-02, -6.1902e-02,  2.9306e-02, -3.7881e-02,  2.7795e-05,
#                        2.1981e-03], device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_v.weight',
#               tensor([[ 0.1075, -0.0716,  0.0277,  ...,  0.0820, -0.0822,  0.0243],
#                       [-0.0192,  0.0670, -0.0221,  ..., -0.0703, -0.0482, -0.0665],
#                       [-0.0228, -0.0669, -0.0742,  ...,  0.0921, -0.0037, -0.1017],
#                       ...,
#                       [-0.0331,  0.0388,  0.0274,  ...,  0.0446,  0.0607,  0.0252],
#                       [ 0.0942, -0.0641, -0.0807,  ..., -0.0146,  0.0072, -0.0741],
#                       [-0.0159, -0.0273, -0.0202,  ...,  0.0697, -0.0415,  0.0297]],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_v.bias',
#               tensor([ 0.0857,  0.0406, -0.0003,  0.0927,  0.0596, -0.0657, -0.0390,  0.0359,
#                       -0.0606, -0.0101, -0.0452,  0.0517,  0.0413,  0.0420,  0.0028,  0.0189],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_o.weight',
#               tensor([[-0.1249, -0.1585,  0.1759,  ..., -0.1331, -0.1112,  0.1598],
#                       [-0.1982,  0.0063, -0.1206,  ..., -0.2114,  0.1737, -0.0748],
#                       [-0.2364,  0.0534,  0.0611,  ..., -0.1577,  0.1164, -0.2660],
#                       ...,
#                       [-0.1885, -0.1915, -0.2382,  ..., -0.1535, -0.0498,  0.1974],
#                       [ 0.0694, -0.0282,  0.0171,  ..., -0.2694,  0.1020,  0.2415],
#                       [-0.1134,  0.1634,  0.0659,  ...,  0.1310, -0.2434,  0.1932]],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._selfAttention._W_o.bias',
#               tensor([-0.1658, -0.1997,  0.0494,  0.2216, -0.0853,  0.0076,  0.0605, -0.1403,
#                        0.1991, -0.0771, -0.1680, -0.1099,  0.2296,  0.0296,  0.1681,  0.0775,
#                        0.1746,  0.1121, -0.0230,  0.1643, -0.0896, -0.0613,  0.0714, -0.0119,
#                        0.1842, -0.1351, -0.1097, -0.0835,  0.0623, -0.0610, -0.1051,  0.1955,
#                        0.2175, -0.0064, -0.2163,  0.2131, -0.1315, -0.0490,  0.0638, -0.2063,
#                        0.2021, -0.0109, -0.2481,  0.1083, -0.0243, -0.2066, -0.1147,  0.1180,
#                       -0.0697, -0.1485,  0.0769, -0.1374, -0.0082,  0.1837, -0.1489,  0.1947,
#                        0.0871,  0.1935,  0.2060, -0.1134, -0.0650,  0.0347,  0.1370,  0.0323,
#                       -0.0473, -0.0112,  0.1056, -0.1500,  0.1791, -0.1117,  0.1959, -0.1551,
#                        0.1374,  0.0725,  0.1807, -0.1797, -0.1576, -0.1679, -0.0818, -0.1487,
#                        0.0136,  0.0250, -0.0386, -0.0890, -0.0721, -0.1228, -0.1204,  0.0877,
#                       -0.1733,  0.0095,  0.0620, -0.0375, -0.1446, -0.1760, -0.1091,  0.0124,
#                       -0.1626,  0.1740, -0.1658,  0.1648, -0.1794, -0.2340, -0.1860,  0.1436,
#                       -0.2076, -0.1591,  0.1799, -0.1992, -0.1165, -0.0904,  0.0503, -0.2049,
#                        0.1115,  0.0398, -0.1401,  0.1478, -0.2062,  0.0631,  0.0227, -0.1189,
#                        0.0384, -0.0047,  0.1488, -0.1360, -0.1522, -0.2320,  0.0249,  0.1453],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._feedForward._linear1.weight',
#               tensor([[-0.0584, -0.0614,  0.0164,  ..., -0.0045,  0.0205, -0.0796],
#                       [ 0.0797, -0.0524,  0.0412,  ..., -0.0136, -0.0392, -0.0161],
#                       [-0.0829, -0.0006,  0.0265,  ..., -0.0478, -0.0674, -0.1000],
#                       ...,
#                       [-0.0027, -0.0290,  0.0290,  ...,  0.0771, -0.0036,  0.0440],
#                       [ 0.0721,  0.0033,  0.0459,  ...,  0.0587, -0.0700, -0.0142],
#                       [ 0.0654, -0.0961,  0.0581,  ..., -0.0381, -0.0144, -0.0050]],
#                      device='cuda:0')),
#              ('module.layers_encoding.2._feedForward._linear1.bias',
#               tensor([-0.0605, -0.0559, -0.0230,  ...,  0.0174, -0.0900,  0.0456],
#                      device='cuda:0')),
#              ('module.layers_encoding.2
#                       -4.0753e-03,  1.4907e-03, -3.1827e-03, -2.5277e-02,  3.7950e-02,
#                       -3.6124e-02, -2.7429e-02,  1.4378e-02, -4.1046e-02,  3.0454e-02,
#                        4.9900e-04,  1.4591e-02, -1.4649e-02], device='cuda:0')),
#              ('module.layers_encoding.2._layerNorm2.weight',
#               tensor([1.0497, 1.0161, 1.0335, 1.0305, 1.0214, 1.0237, 1.0604, 1.0912, 0.9952,
#                       1.0420, 1.0127, 1.0081, 1.0761, 1.0306, 1.0422, 1.0917, 1.0185, 1.0091,
#                       1.0246, 1.0051, 1.0011, 1.0685, 0.9913, 1.0222, 1.0499, 0.9933, 1.0101,
#                       1.0357, 1.0296, 0.9978, 1.0296, 1.0542, 1.0751, 1.0200, 1.0423, 1.0421,
#                       0.9871, 1.0321, 1.0026, 1.0166, 1.0217, 1.0255, 1.0389, 0.9876, 1.0353,
#                       1.0090, 0.9972, 1.0113, 1.0392, 1.0525, 1.0152, 0.9964, 1.0219, 0.9823,
#                       1.0483, 1.0482, 1.0173, 1.0085, 1.0668, 1.0690, 0.9612, 1.0228, 1.0076,
#                       0.9731, 1.0179, 0.9789, 0.9985, 1.0150, 1.0020, 0.9782, 1.0082, 1.0194,
#                       1.0336, 1.0395, 1.0422, 1.0345, 1.0419, 1.0308, 1.0723, 0.9569, 1.0263,
#                       1.0062, 1.0770, 1.0190, 1.0720, 1.0090, 1.0061, 1.0047, 0.9864, 1.0193,
#                       1.0158, 1.0180, 0.9921, 1.0258, 1.0283, 1.0137, 1.0194, 0.9917, 1.0246,
#                       1.0108, 1.0209, 0.9856, 0.9919, 1.0873, 1.0326, 1.0140, 1.0066, 1.0325,
#                       0.9996, 1.0009, 1.0012, 0.9975, 1.0703, 0.9724, 1.0191, 1.0111, 1.0108,
#                       0.9949, 0.9918, 1.0110, 0.9727, 1.0066, 1.0124, 1.0552, 1.0146, 0.9973,
#                       1.0515, 0.9819], device='cuda:0')),
#              ('module.layers_encoding.2._layerNorm2.bias',
#               tensor([ 4.1974e-02,  9.9402e-03, -1.4772e-02, -7.8212e-03, -2.9763e-02,
#                        2.8035e-02, -8.0628e-03, -1.7678e-02, -1.7961e-02,  8.2951e-02,
#                        1.7629e-02,  1.6914e-02, -1.7041e-02,  4.7234e-02,  2.5586e-02,
#                       -1.9605e-02,  4.4854e-03,  6.2121e-02,  3.0829e-02,  1.2191e-02,
# ...
#                      device='cuda:0')),
#              ('module.layers_decoding.2._feedForward._linear2.weight',
#               tensor([[ 0.0199,  0.0105,  0.0209,  ..., -0.0046, -0.0044,  0.0095],
#                       [-0.0100,  0.0242, -0.0180,  ..., -0.0225,  0.0170,  0.0041],
#                       [ 0.0048,  0.0151, -0.0142,  ..., -0.0076,  0.0033,  0.0021],
#                       ...,
#                       [ 0.0139, -0.0233,  0.0049,  ...,  0.0188,  0.0197,  0.0124],
#                       [-0.0004,  0.0258,  0.0055,  ..., -0.0114, -0.0106, -0.0029],
#                       [-0.0122,  0.0171,  0.0034,  ..., -0.0274,  0.0157,  0.0115]],
='cuda:0')),
#              ('module.layers_decoding.2._layerNorm3.weight',
#               tensor([1.1176, 1.0543, 1.0515, 1.0311, 1.1459, 1.0770, 1.0800, 1.0530, 1.0317,
#                       1.1726, 1.0305, 1.0556, 1.0878, 1.0702, 1.0566, 1.1161, 1.0927, 1.0771,
#                       1.1060, 1.0885, 1.0630, 1.1036, 1.0393, 1.1015, 1.0492, 1.0476, 1.0377,
#                       1.0271, 1.1074, 1.0419, 1.1156, 1.0827, 1.0563, 1.0278, 1.0489, 1.0374,
#                       1.0280, 1.0605, 1.0650, 1.0350, 1.0438, 1.1226, 1.0902, 1.1038, 1.1446,
#                       1.0653, 1.0807, 1.0266, 1.0404, 1.0910, 1.0647, 1.0225, 1.0603, 1.0324,
#                       1.0155, 1.0265, 1.0521, 1.1077, 1.0552, 1.0769, 1.0220, 1.0310, 1.0282,
#                       1.0232, 1.0250, 1.0174, 1.0293, 1.0266, 1.0659, 1.0967, 1.0474, 1.0377,
#                       1.0601, 1.0911, 1.0246, 0.9896, 1.0331, 1.0613, 1.0278, 1.0889, 1.0301,
#                       1.0546, 1.0232, 1.0442, 1.1012, 1.0859, 1.0368, 1.0551, 1.0370, 1.1478,
#                       1.0261, 1.0468, 1.0652, 1.0244, 1.0437, 1.0701, 1.0626, 1.1037, 1.0469,
#                       1.0534, 1.1194, 1.0285, 1.0311, 1.0282, 1.1125, 1.0568, 1.0227, 1.0381,
#                       1.0581, 1.0519, 1.0720, 1.0293, 1.0465, 1.0170, 1.0874, 1.0261, 1.0247,
#                       1.1073, 1.0750, 1.0761, 1.0267, 1.0969, 1.0679, 1.0319, 1.0368, 1.0641,
#                       1.0651, 1.0617], device='cuda:0')),
#              ('module.layers_decoding.2._layerNorm3.bias',
#               tensor([ 0.0434,  0.0435,  0.0448, -0.0439, -0.0431,  0.0428, -0.0429, -0.0460,
#                       -0.0443,  0.0433,  0.0436,  0.0450, -0.0430,  0.0428,  0.0427, -0.0434,
#                       -0.0429,  0.0436,  0.0433,  0.0434,  0.0435, -0.0437, -0.0515, -0.0427,
#                       -0.0436,  0.0443, -0.0493, -0.0455,  0.0435,  0.0444, -0.0435, -0.0448,
#                       -0.0429,  0.0437, -0.0453,  0.0514,  0.0444, -0.0443, -0.0437, -0.0449,
#                        0.0435, -0.0436,  0.0428,  0.0449, -0.0434, -0.0428,  0.0427, -0.0438,
#                        0.0430,  0.0430,  0.0460,  0.0431,  0.0457, -0.0443, -0.0466, -0.0437,
#                       -0.0444, -0.0428,  0.0428,  0.0429,  0.0443,  0.0453,  0.0442, -0.0431,
#                       -0.0352, -0.0427,  0.0438, -0.0481,  0.0474,  0.0433,  0.0427, -0.0439,
#                       -0.0446, -0.0428,  0.0443,  0.0492, -0.0459, -0.0431, -0.0440,  0.0430,
#                       -0.0438,  0.0436,  0.0437, -0.0433, -0.0442, -0.0431,  0.0428, -0.0433,
#                        0.0461, -0.0430,  0.0468,  0.0427,  0.0446,  0.0434, -0.0440,  0.0430,
#                       -0.0433, -0.0439, -0.0457, -0.0482,  0.0435, -0.0439, -0.0436,  0.0437,
#                        0.0428, -0.0434,  0.0471, -0.0438, -0.0427, -0.0465,  0.0428,  0.0436,
#                        0.0474,  0.0454,  0.0430,  0.0437, -0.0426,  0.0435, -0.0429,  0.0428,
#                       -0.0440, -0.0434, -0.0442, -0.0442, -0.0446, -0.0444,  0.0456,  0.0460],
#                      device='cuda:0')),
#              ('module._embedding.weight',
#               tensor([[ 0.0057, -0.1619, -0.2019,  ..., -0.1825,  0.0209, -0.0671],
#                       [ 0.0090, -0.0883,  0.0982,  ...,  0.0865, -0.1679, -0.0125],
#                       [-0.0128, -0.0157,  0.0561,  ..., -0.0273,  0.0565, -0.1362],
#                       ...,
#                       [-0.1393, -0.0292, -0.0021,  ...,  0.1398,  0.0035,  0.2092],
#                       [-0.0989, -0.1414,  0.0521,  ...,  0.0100, -0.0375, -0.0667],
#                       [ 0.0533, -0.0493,  0.0949,  ...,  0.0452,  0.1670, -0.0855]],
#                      device='cuda:0')),
#              ('module._embedding.bias',
#               tensor([-0.0611,  0.0765,  0.1556,  0.1518, -0.0591, -0.1276,  0.0943,  0.0665,
#                        0.0220, -0.0174,  0.1019, -0.1238, -0.2158,  0.0170,  0.0340,  0.1245,
#                        0.0959,  0.0129,  0.0715, -0.1495, -0.1302,  0.1023, -0.0685, -0.1230,
#                       -0.0755,  0.1186, -0.0827,  0.0875,  0.1840, -0.1197,  0.1753,  0.0658,
#                        0.0060, -0.1100,  0.0326,  0.1392, -0.0979,  0.0357, -0.0216, -0.0316,
#                        0.0766,  0.2513, -0.0165, -0.1281,  0.0329, -0.1428,  0.0490, -0.0815,
#                       -0.1496,  0.0596,  0.1558,  0.1360, -0.0362, -0.0705, -0.0041,  0.0806,
#                        0.1204, -0.1299, -0.0246,  0.1125,  0.0473,  0.0633, -0.0209,  0.1242,
#                       -0.2048, -0.0775, -0.0256, -0.0090,  0.0653,  0.0189, -0.0041,  0.0138,
#                       -0.1169, -0.0010, -0.0211,  0.1263, -0.0443,  0.0567,  0.0528,  0.1137,
#                        0.1888,  0.1374, -0.1301, -0.0517,  0.0075,  0.0060, -0.0321,  0.1389,
#                       -0.1694, -0.1415, -0.0485,  0.1693,  0.0942, -0.1597, -0.0517,  0.1736,
#                       -0.1512, -0.1209, -0.0098, -0.1592, -0.0835,  0.0827,  0.0047, -0.0345,
#                       -0.0832, -0.0923,  0.1376, -0.0365,  0.1272, -0.1147,  0.0820, -0.1547,
#                       -0.0199,  0.1845, -0.1018, -0.0247,  0.0532, -0.1455,  0.0576,  0.0376,
#                       -0.0195, -0.0651, -0.0677,  0.0666,  0.1728,  0.0222, -0.0569,  0.1723],
#                      device='cuda:0')),
#              ('module._linear.weight',
#               tensor([[-0.1527, -0.0892, -0.0795,  0.0585,  0.2127, -0.1534,  0.1545,  0.0623,
#                         0.0501, -0.2040, -0.0672, -0.0714,  0.1500, -0.1332, -0.1336,  0.1775,
#                         0.1670, -0.1083, -0.1675, -0.1280, -0.1074,  0.1375,  0.0308,  0.1791,
#                         0.0944, -0.0798,  0.0336,  0.0312, -0.1552, -0.0699,  0.1599,  0.1041,
#                         0.1205, -0.0637,  0.0647, -0.0303, -0.0449,  0.0862,  0.0923,  0.0475,
#                        -0.0788,  0.1570, -0.1668, -0.1090,  0.1997,  0.1445, -0.1607,  0.0549,
#                        -0.0873, -0.1467, -0.0751, -0.0697, -0.0644,  0.0524,  0.0201,  0.0554,
#                         0.0700,  0.1876, -0.1241, -0.1546, -0.0412, -0.0377, -0.0468,  0.0736,
#                         0.0238,  0.0923, -0.0500,  0.0282, -0.0677, -0.1341, -0.1276,  0.0720,
#                         0.0772,  0.1705, -0.0460,  0.0030,  0.0356,  0.1229,  0.0491, -0.1494,
#                         0.0505, -0.0932, -0.0526,  0.0942,  0.1267,  0.1420, -0.1136,  0.1071,
#                        -0.0474,  0.2169, -0.0314, -0.1261, -0.0977, -0.0587,  0.0667, -0.1214,
#                         0.1105,  0.1349,  0.0637,  0.0550, -0.1702,  0.0527,  0.0653, -0.0592,
#                        -0.1890,  0.1006, -0.0259,  0.0609,  0.1403,  0.0549, -0.1496, -0.0656,
#                        -0.0453, -0.0264, -0.1546, -0.0577,  0.1079, -0.1393,  0.1435, -0.1474,
#                         0.0525,  0.1444,  0.0876,  0.0547,  0.0521,  0.0886, -0.0784, -0.0715]],
#                      device='cuda:0')),
#              ('module._linear.bias', tensor([-0.0847], device='cuda:0'))])

# %%
model = Transformer(tOpt)

# %%
model.load_state_dict(local_state_dict)
# Out:
# <All keys matched successfully>

# %%
def load_data(local_rank, world_size, epoch_idx, total_epoch, mode = 'train'):
    if not epoch_idx:
        epoch_idx = 0
    rs = ut.redis_connection(db = 0)
    world_dict = ut.read_data_from_redis(rs, f'{mode}_world_dict_{world_size}_epoch_{total_epoch}')
    keys = world_dict[epoch_idx][local_rank]

    data = []
    for k in keys:
        k_numpy = ut.read_data_from_redis(rs, k)
        if len(k_numpy) > 4800:
            continue
        data.append(k_numpy)
    rs.close()

    return data

# %%
test_data = load_data(0, 1, epoch_idx = None, total_epoch = 1, mode = 'test')

# %%
test_dataset = HFTestDataset(test_data[:500], tick_num = tOpt.window)

# %%
test_dataloader = DataLoader(test_dataset,
                             batch_size=2,
                             num_workers=1,
                             shuffle = False)

# %%
y_pred_all = []
y_all = []

# %%
model.eval()
# Out:
# Transformer(
#   (layers_encoding): ModuleList(
#     (0): Encoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#     (1): Encoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#     (2): Encoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (layers_decoding): ModuleList(
#     (0): Decoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_encoderDecoderAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm3): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#     (1): Decoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_encoderDecoderAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm3): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#     (2): Decoder(
#       (_selfAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_encoderDecoderAttention): MultiHeadAttentionWindow(
#         (_W_q): Linear(in_features=128, out_features=16, bias=True)
#         (_W_k): Linear(in_features=128, out_features=16, bias=True)
#         (_W_v): Linear(in_features=128, out_features=16, bias=True)
#         (_W_o): Linear(in_features=16, out_features=128, bias=True)
#       )
#       (_feedForward): PositionwiseFeedForward(
#         (_linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (_linear2): Linear(in_features=2048, out_features=128, bias=True)
#       )
#       (_layerNorm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_layerNorm3): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (_dropout): Dropout(p=0.3, inplace=False)
#     )
#   )
#   (_embedding): Linear(in_features=43, out_features=128, bias=True)
#   (_linear): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
model = model.cuda()

# %%
with torch.no_grad():
    for x, y in tqdm(test_dataloader, total=len(test_dataloader)):
        y_pred = model(x.cuda()).to('cpu') 
        y_pred_all.append(y_pred.detach().numpy())
        y_all.append(y.detach().numpy())
# Out:
#   2%|██▏                                                                                                                              | 3971/240000 [00:36<35:46, 109.97it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [19], in <module>
#       1 with torch.no_grad():
# ----> 2     for x, y in tqdm(test_dataloader, total=len(test_dataloader)):
#       3         y_pred = model(x.cuda()).to('cpu')
#       4         y_pred_all.append(y_pred.detach().numpy())
#
# File ~/usr/anaconda3/envs/learning/lib/python3.9/site-packages/tqdm/std.py:1180, in tqdm.__iter__(self)
#    1177 time = self._time
#    1179 try:
# -> 1180     for obj in iterable:
#    1181         yield obj
#    1182         # Update and possibly print the progressbar.
#    1183         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/usr/anaconda3/envs/learning/lib/python3.9/site-packages/torch/utils/data/dataloader.py:521, in _BaseDataLoaderIter.__next__(self)
#     519 if self._sampler_iter is None:
#     520     self._reset()
# --> 521 data = self._next_data()
#     522 self._num_yielded += 1
#     523 if self._dataset_kind == _DatasetKind.Iterable and \
#     524         self._IterableDataset_len_called is not None and \
#     525         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/usr/anaconda3/envs/learning/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1186, in _MultiProcessingDataLoaderIter._next_data(self)
#    1183     return self._process_data(data)
#    1185 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186 idx, data = self._get_data()
#    1187 self._tasks_outstanding -= 1
#    1188 if self._dataset_kind == _DatasetKind.Iterable:
#    1189     # Check for _IterableDatasetStopIteration
#
# File ~/usr/anaconda3/envs/learning/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1152, in _MultiProcessingDataLoaderIter._get_data(self)
#    1148     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1149     # need to call `.task_done()` because we don't use `.join()`.
#    1150 else:
#    1151     while True:
# -> 1152         success, data = self._try_get_data()
#    1153         if success:
#    1154             return data
#
# File ~/usr/anaconda3/envs/learning/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1017, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1015 except OSError as e:
#    1016     if e.errno == errno.EMFILE:
# -> 1017         raise RuntimeError(
#    1018             "Too many open files. Communication with the"
#    1019             " workers is no longer possible. Please increase the"
#    1020             " limit using `ulimit -n` in the shell or change the"
#    1021             " sharing strategy by calling"
#    1022             " `torch.multiprocessing.set_sharing_strategy('file_system')`"
#    1023             " at the beginning of your code") from None
#    1024 raise
#
# RuntimeError: Too many open files. Communication with the workers is no longer possible. Please increase the limit using `ulimit -n` in the shell or change the sharing strategy by calling `torch.multiprocessing.set_sharing_strategy('file_system')` at the beginning of your code

# %%
from scipy.stats import spearmanr

# %%
y_pred_concat = np.concatenate(y_pred_all)
y_concat = np.concatenate(y_all)
y_pred_concat = y_pred_concat.reshape(-1, 1)
y_concat = y_concat.reshape(-1, 1)

# %%
spearmanr(y_pred_concat, y_concat)

# %%
encoder = model.layers_encoding[0]
attn_map = encoder.attention_map[0].cpu()

# %%
# Plot
plt.figure(figsize=(12, 12))
sns.heatmap(attn_map)
plt.savefig("attention_map")
